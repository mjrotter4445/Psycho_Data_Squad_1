# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df_DA=pd.read_csv('DataAnalyst.csv')
df_DA
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 16 columns]

# %%
df_DA = df_DA.rename(columns={'Job Title': 'Job_Title', 'Salary Estimate': 'Salary_Estimate', 'Job Description': 'Job_Description', 'Company Name': 'Company_Name', 'Type of ownership': 'Type_of_ownership', 'Easy Apply': 'Easy_Apply','Analyst Job': 'Analyst_Job'})
df_DA.head()
# Out:
#    Unnamed: 0                                          Job_Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary_Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job_Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company_Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type_of_ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy_Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
df_DA = df_DA.drop(['Unnamed: 0','Headquarters'],axis=1)

# %%
null_columns=df_DA.columns[df_DA.isnull().any()]
df_DA[null_columns].isnull().sum()
# Out:
# Company_Name    1
# dtype: int64

# %%
print(df_DA[df_DA["Company_Name"].isnull()][null_columns])
# Out:
#      Company_Name
# 1860          NaN

# %%
df_DA.dropna(how="any",inplace=True)

# %%
null_columns=df_DA.columns[df_DA.isnull().any()]
df_DA[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
df_DA.dtypes
# Out:
# Job_Title             object
# Salary_Estimate       object
# Job_Description       object
# Rating               float64
# Company_Name          object
# Location              object
# Size                  object
# Founded                int64
# Type_of_ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# Easy_Apply            object
# dtype: object

# %%
df_DA['Job_Title'],df_DA['Department']= df_DA['Job_Title'].str.split(',',1).str
# Out:
# /Users/JustinCLee/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.

# %%
df_DA['Company_Name'],_ = df_DA['Company_Name'].str.split('\n',1).str
df_DA['Salary_Estimate'],_= df_DA['Salary_Estimate'].str.split('(',1).str
df_DA['Min_Salary'],df_DA['Max_Salary']= df_DA['Salary_Estimate'].str.split('-').str
# Out:
# /Users/JustinCLee/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.
# /Users/JustinCLee/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#
# /Users/JustinCLee/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
clean_salary = lambda x: x.replace('', np.nan).str.strip().str.lstrip('$').str.rstrip('K').fillna(0).astype(int)

# %%
df_DA['Min_Salary'] = clean_salary(df_DA['Min_Salary'])
df_DA['Max_Salary'] = clean_salary(df_DA['Max_Salary'])
# df_DA["Salary_Estimate"] = clean_salary(df_DA['Salary_Estimate'])

df_DA = df_DA.drop(['Salary_Estimate'],axis = 1)

df_DA.head()
# Out:
#                 Job_Title                                    Job_Description  \
# 0            Data Analyst  Are you eager to roll up your sleeves and harn...
# 1    Quality Data Analyst  Overview\n\nProvides analytical and technical ...
# 2     Senior Data Analyst  We’re looking for a Senior Data Analyst who ha...
# 3            Data Analyst  Requisition NumberRR-0001939\nRemote:Yes\nWe c...
# 4  Reporting Data Analyst  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
#
#    Rating                        Company_Name      Location  \
# 0     3.2           Vera Institute of Justice  New York, NY
# 1     3.8  Visiting Nurse Service of New York  New York, NY
# 2     3.4                         Squarespace  New York, NY
# 3     4.1                            Celerity  New York, NY
# 4     3.9                             FanDuel  New York, NY
#
#                      Size  Founded               Type_of_ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy_Apply  \
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True
#
#                                          Department  Min_Salary  Max_Salary
# 0           Center on Immigration and Justice (CIJ)          37          66
# 1                                               NaN          37          66
# 2   Insights & Analytics Team [Customer Operations]          37          66
# 3                                               NaN          37          66
# 4                                               NaN          37          66

# %%
new_column = []

def word_search(column):
    for element in column:
        my_list = element.split()
        if 'Senior' in my_list:
            new_column.append('True')
        elif "Sr." in my_list:
            new_column.append("True")
        else:
            new_column.append('False')

# %%
word_search(df_DA["Job_Title"])

# %%
len(df_DA)
# Out:
# 2252

# %%
len(new_column)
# Out:
# 2252

# %%
df_DA["Senior_Job"] = new_column

# %%
df_DA.head()
# Out:
#                 Job_Title                                    Job_Description  \
# 0            Data Analyst  Are you eager to roll up your sleeves and harn...
# 1    Quality Data Analyst  Overview\n\nProvides analytical and technical ...
# 2     Senior Data Analyst  We’re looking for a Senior Data Analyst who ha...
# 3            Data Analyst  Requisition NumberRR-0001939\nRemote:Yes\nWe c...
# 4  Reporting Data Analyst  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
#
#    Rating                        Company_Name      Location  \
# 0     3.2           Vera Institute of Justice  New York, NY
# 1     3.8  Visiting Nurse Service of New York  New York, NY
# 2     3.4                         Squarespace  New York, NY
# 3     4.1                            Celerity  New York, NY
# 4     3.9                             FanDuel  New York, NY
#
#                      Size  Founded               Type_of_ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy_Apply  \
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True
#
#                                          Department  Min_Salary  Max_Salary  \
# 0           Center on Immigration and Justice (CIJ)          37          66
# 1                                               NaN          37          66
# 2   Insights & Analytics Team [Customer Operations]          37          66
# 3                                               NaN          37          66
# 4                                               NaN          37          66
#
#   Senior_Job
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False

# %%
job_list = df_DA['Job_Title'].value_counts()
full_job_list = list(job_list)

# %%
import matplotlib.pyplot as plt
plt.plot(full_job_list)

plt.plot()
# Out:
# []

# %%
replace_application = (job_list[job_list < 17].index)

# Replace in dataframe
for app in replace_application:
    df_DA['Job_Title'] = df_DA['Job_Title'].replace(app,"Other")
    
# Check to make sure binning was successful
df_DA['Job_Title'].value_counts()
# Out:
# Other                    1547
# Data Analyst              442
# Senior Data Analyst       105
# Junior Data Analyst        30
# Business Data Analyst      28
# Sr. Data Analyst           26
# Data Analyst II            20
# Lead Data Analyst          19
# Data Quality Analyst       18
# Data Analyst Junior        17
# Name: Job_Title, dtype: int64

# %%
salary_column = []

def sal_search(column):
    for element in column:
        if element > 100:
            salary_column.append("High")
        elif element > 75:
            salary_column.append("Medium")
        else:
            salary_column.append("Low")

# %%
sal_search(df_DA["Max_Salary"])

# %%
len(df_DA)
# Out:
# 2252

# %%
len(salary_column)
# Out:
# 2252

# %%
df_DA["Salary_Lvl"] = salary_column

# %%
df_DA
# Out:
#                 Job_Title                                    Job_Description  \
# 0            Data Analyst  Are you eager to roll up your sleeves and harn...
# 1                   Other  Overview\n\nProvides analytical and technical ...
# 2     Senior Data Analyst  We’re looking for a Senior Data Analyst who ha...
# 3            Data Analyst  Requisition NumberRR-0001939\nRemote:Yes\nWe c...
# 4                   Other  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
# ...                   ...                                                ...
# 2248                Other  Maintains systems to protect data from unautho...
# 2249                Other  Position:\nSenior Data Analyst (Corporate Audi...
# 2250                Other  Title: Technical Business Analyst (SQL, Data a...
# 2251                Other  Summary\n\nResponsible for working cross-funct...
# 2252                Other  You.\n\nYou bring your body, mind, heart and s...
#
#       Rating                        Company_Name        Location  \
# 0        3.2           Vera Institute of Justice    New York, NY
# 1        3.8  Visiting Nurse Service of New York    New York, NY
# 2        3.4                         Squarespace    New York, NY
# 3        4.1                            Celerity    New York, NY
# 4        3.9                             FanDuel    New York, NY
# ...      ...                                 ...             ...
# 2248     2.5                       Avacend, Inc.      Denver, CO
# 2249     2.9                   Arrow Electronics  Centennial, CO
# 2250     NaN                            Spiceorb      Denver, CO
# 2251     3.1         Contingent Network Services  Centennial, CO
# 2252     3.4                          SCL Health  Broomfield, CO
#
#                         Size  Founded               Type_of_ownership  \
# 0       201 to 500 employees   1961.0          Nonprofit Organization
# 1           10000+ employees   1893.0          Nonprofit Organization
# 2     1001 to 5000 employees   2003.0               Company - Private
# 3       201 to 500 employees   2002.0  Subsidiary or Business Segment
# 4      501 to 1000 employees   2009.0               Company - Private
# ...                      ...      ...                             ...
# 2248     51 to 200 employees      NaN               Company - Private
# 2249        10000+ employees   1935.0                Company - Public
# 2250                     NaN      NaN                             NaN
# 2251    201 to 500 employees   1984.0               Company - Private
# 2252        10000+ employees   1864.0          Nonprofit Organization
#
#                                      Industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply  \
# 0                                                   NaN       True
# 1                                                   NaN        NaN
# 2                                               GoDaddy        NaN
# 3                                                   NaN        NaN
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN        NaN
# 2249                     Avnet, Ingram Micro, Tech Data        NaN
# 2250                                                NaN        NaN
# 2251                                                NaN        NaN
# 2252  Centura Health, HealthONE, Denver Health and H...        NaN
#
#                                             Department  Min_Salary  \
# 0              Center on Immigration and Justice (CIJ)          37
# 1                                                  NaN          37
# 2      Insights & Analytics Team [Customer Operations]          37
# 3                                                  NaN          37
# 4                                                  NaN          37
# ...                                                ...         ...
# 2248                                               NaN          78
# 2249                                               NaN          78
# 2250                              Data analytics, ETL)          78
# 2251                               Customer Experience          78
# 2252                                               NaN          78
#
#       Max_Salary Senior_Job Salary_Lvl
# 0             66      False        Low
# 1             66      False        Low
# 2             66       True        Low
# 3             66      False        Low
# 4             66      False        Low
# ...          ...        ...        ...
# 2248         104      False       High
# 2249         104       True       High
# 2250         104      False       High
# 2251         104      False       High
# 2252         104       True       High
#
# [2252 rows x 18 columns]

# %%
df_DA.replace(to_replace="-1", value=np.nan, inplace=True)

# %%
df_DA.replace(to_replace=-1, value=np.nan, inplace=True)

# %%
df_DA
# Out:
#                 Job_Title                                    Job_Description  \
# 0            Data Analyst  Are you eager to roll up your sleeves and harn...
# 1                   Other  Overview\n\nProvides analytical and technical ...
# 2     Senior Data Analyst  We’re looking for a Senior Data Analyst who ha...
# 3            Data Analyst  Requisition NumberRR-0001939\nRemote:Yes\nWe c...
# 4                   Other  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
# ...                   ...                                                ...
# 2248                Other  Maintains systems to protect data from unautho...
# 2249                Other  Position:\nSenior Data Analyst (Corporate Audi...
# 2250                Other  Title: Technical Business Analyst (SQL, Data a...
# 2251                Other  Summary\n\nResponsible for working cross-funct...
# 2252                Other  You.\n\nYou bring your body, mind, heart and s...
#
#       Rating                        Company_Name        Location  \
# 0        3.2           Vera Institute of Justice    New York, NY
# 1        3.8  Visiting Nurse Service of New York    New York, NY
# 2        3.4                         Squarespace    New York, NY
# 3        4.1                            Celerity    New York, NY
# 4        3.9                             FanDuel    New York, NY
# ...      ...                                 ...             ...
# 2248     2.5                       Avacend, Inc.      Denver, CO
# 2249     2.9                   Arrow Electronics  Centennial, CO
# 2250     NaN                            Spiceorb      Denver, CO
# 2251     3.1         Contingent Network Services  Centennial, CO
# 2252     3.4                          SCL Health  Broomfield, CO
#
#                         Size  Founded               Type_of_ownership  \
# 0       201 to 500 employees   1961.0          Nonprofit Organization
# 1           10000+ employees   1893.0          Nonprofit Organization
# 2     1001 to 5000 employees   2003.0               Company - Private
# 3       201 to 500 employees   2002.0  Subsidiary or Business Segment
# 4      501 to 1000 employees   2009.0               Company - Private
# ...                      ...      ...                             ...
# 2248     51 to 200 employees      NaN               Company - Private
# 2249        10000+ employees   1935.0                Company - Public
# 2250                     NaN      NaN                             NaN
# 2251    201 to 500 employees   1984.0               Company - Private
# 2252        10000+ employees   1864.0          Nonprofit Organization
#
#                                      Industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply  \
# 0                                                   NaN       True
# 1                                                   NaN        NaN
# 2                                               GoDaddy        NaN
# 3                                                   NaN        NaN
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN        NaN
# 2249                     Avnet, Ingram Micro, Tech Data        NaN
# 2250                                                NaN        NaN
# 2251                                                NaN        NaN
# 2252  Centura Health, HealthONE, Denver Health and H...        NaN
#
#                                             Department  Min_Salary  \
# 0              Center on Immigration and Justice (CIJ)          37
# 1                                                  NaN          37
# 2      Insights & Analytics Team [Customer Operations]          37
# 3                                                  NaN          37
# 4                                                  NaN          37
# ...                                                ...         ...
# 2248                                               NaN          78
# 2249                                               NaN          78
# 2250                              Data analytics, ETL)          78
# 2251                               Customer Experience          78
# 2252                                               NaN          78
#
#       Max_Salary Senior_Job
# 0             66      False
# 1             66      False
# 2             66       True
# 3             66      False
# 4             66      False
# ...          ...        ...
# 2248         104      False
# 2249         104       True
# 2250         104      False
# 2251         104      False
# 2252         104       True
#
# [2252 rows x 17 columns]

# %%
df_DA["Revenue"].unique()
# Out:
# array(['$100 to $500 million (USD)', '$2 to $5 billion (USD)',
#        'Unknown / Non-Applicable', '$50 to $100 million (USD)',
#        '$1 to $2 billion (USD)', '$5 to $10 billion (USD)',
#        '$1 to $5 million (USD)', '$25 to $50 million (USD)',
#        '$10+ billion (USD)', 'Less than $1 million (USD)',
#        '$10 to $25 million (USD)', nan,
#        '$500 million to $1 billion (USD)', '$5 to $10 million (USD)'],
#       dtype=object)

# %%
df_DA["Size"].unique()
# Out:
# array(['201 to 500 employees', '10000+ employees',
#        '1001 to 5000 employees', '501 to 1000 employees',
#        '5001 to 10000 employees', '1 to 50 employees',
#        '51 to 200 employees', 'Unknown', nan], dtype=object)

# %%
def recode(column, new_code):
    col_cod = pd.Series(column, copy = True)
    for key, values in new_code.items():
        col_cod.replace(key, values, inplace = True)
    return col_cod

# %%
df_DA['Easy_Apply'] = recode(df_DA['Easy_Apply'],{np.NaN:0,'True':1})


df_easy_apply = df_DA[df_DA['Easy_Apply'] == 1]
df_easy_apply.reset_index()
df_easy_apply.head()
# Out:
#               Job_Title                                    Job_Description  \
# 0          Data Analyst  Are you eager to roll up your sleeves and harn...
# 4                 Other  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
# 7                 Other  Data Science Analyst\n\nJob Details\nLevel\nEx...
# 13  Senior Data Analyst  About Known\n\nKnown is a modern marketing com...
# 16         Data Analyst  Undertone stands alone among AdTech and ad net...
#
#     Rating               Company_Name      Location                   Size  \
# 0      3.2  Vera Institute of Justice  New York, NY   201 to 500 employees
# 4      3.9                    FanDuel  New York, NY  501 to 1000 employees
# 7      3.7    GNY Insurance Companies  New York, NY   201 to 500 employees
# 13     3.0                      Known  New York, NY   201 to 500 employees
# 16     3.8                  Undertone  New York, NY   201 to 500 employees
#
#     Founded               Type_of_ownership                 Industry  \
# 0    1961.0          Nonprofit Organization        Social Assistance
# 4    2009.0               Company - Private      Sports & Recreation
# 7    1914.0               Company - Private       Insurance Carriers
# 13   2004.0               Company - Private  Advertising & Marketing
# 16   2001.0  Subsidiary or Business Segment  Advertising & Marketing
#
#                               Sector                     Revenue  \
# 0                         Non-Profit  $100 to $500 million (USD)
# 4   Arts, Entertainment & Recreation  $100 to $500 million (USD)
# 7                          Insurance  $100 to $500 million (USD)
# 13                 Business Services  $100 to $500 million (USD)
# 16                 Business Services    Unknown / Non-Applicable
#
#                                 Competitors  Easy_Apply  \
# 0                                       NaN         1.0
# 4                                DraftKings         1.0
# 7          Travelers, Chubb, Crum & Forster         1.0
# 13                                      NaN         1.0
# 16  DoubleClick, Specific Media, Collective         1.0
#
#                                   Department  Min_Salary  Max_Salary  \
# 0    Center on Immigration and Justice (CIJ)          37          66
# 4                                        NaN          37          66
# 7                                        NaN          37          66
# 13                                       NaN          37          66
# 16                                       NaN          37          66
#
#    Senior_Job Salary_Lvl
# 0       False        Low
# 4       False        Low
# 7       False        Low
# 13       True        Low
# 16      False        Low

# %%
df_DA
# Out:
#                 Job_Title                                    Job_Description  \
# 0            Data Analyst  Are you eager to roll up your sleeves and harn...
# 1                   Other  Overview\n\nProvides analytical and technical ...
# 2     Senior Data Analyst  We’re looking for a Senior Data Analyst who ha...
# 3            Data Analyst  Requisition NumberRR-0001939\nRemote:Yes\nWe c...
# 4                   Other  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
# ...                   ...                                                ...
# 2248                Other  Maintains systems to protect data from unautho...
# 2249                Other  Position:\nSenior Data Analyst (Corporate Audi...
# 2250                Other  Title: Technical Business Analyst (SQL, Data a...
# 2251                Other  Summary\n\nResponsible for working cross-funct...
# 2252                Other  You.\n\nYou bring your body, mind, heart and s...
#
#       Rating                        Company_Name        Location  \
# 0        3.2           Vera Institute of Justice    New York, NY
# 1        3.8  Visiting Nurse Service of New York    New York, NY
# 2        3.4                         Squarespace    New York, NY
# 3        4.1                            Celerity    New York, NY
# 4        3.9                             FanDuel    New York, NY
# ...      ...                                 ...             ...
# 2248     2.5                       Avacend, Inc.      Denver, CO
# 2249     2.9                   Arrow Electronics  Centennial, CO
# 2250     NaN                            Spiceorb      Denver, CO
# 2251     3.1         Contingent Network Services  Centennial, CO
# 2252     3.4                          SCL Health  Broomfield, CO
#
#                         Size  Founded               Type_of_ownership  \
# 0       201 to 500 employees   1961.0          Nonprofit Organization
# 1           10000+ employees   1893.0          Nonprofit Organization
# 2     1001 to 5000 employees   2003.0               Company - Private
# 3       201 to 500 employees   2002.0  Subsidiary or Business Segment
# 4      501 to 1000 employees   2009.0               Company - Private
# ...                      ...      ...                             ...
# 2248     51 to 200 employees      NaN               Company - Private
# 2249        10000+ employees   1935.0                Company - Public
# 2250                     NaN      NaN                             NaN
# 2251    201 to 500 employees   1984.0               Company - Private
# 2252        10000+ employees   1864.0          Nonprofit Organization
#
#                                      Industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors  Easy_Apply  \
# 0                                                   NaN         1.0
# 1                                                   NaN         0.0
# 2                                               GoDaddy         0.0
# 3                                                   NaN         0.0
# 4                                            DraftKings         1.0
# ...                                                 ...         ...
# 2248                                                NaN         0.0
# 2249                     Avnet, Ingram Micro, Tech Data         0.0
# 2250                                                NaN         0.0
# 2251                                                NaN         0.0
# 2252  Centura Health, HealthONE, Denver Health and H...         0.0
#
#                                             Department  Min_Salary  \
# 0              Center on Immigration and Justice (CIJ)          37
# 1                                                  NaN          37
# 2      Insights & Analytics Team [Customer Operations]          37
# 3                                                  NaN          37
# 4                                                  NaN          37
# ...                                                ...         ...
# 2248                                               NaN          78
# 2249                                               NaN          78
# 2250                              Data analytics, ETL)          78
# 2251                               Customer Experience          78
# 2252                                               NaN          78
#
#       Max_Salary Senior_Job Salary_Lvl
# 0             66      False        Low
# 1             66      False        Low
# 2             66       True        Low
# 3             66      False        Low
# 4             66      False        Low
# ...          ...        ...        ...
# 2248         104      False       High
# 2249         104       True       High
# 2250         104      False       High
# 2251         104      False       High
# 2252         104       True       High
#
# [2252 rows x 18 columns]

# %%
df_employed = df_DA['Size'].value_counts().to_frame().reset_index()
df_employed
# Out:
#                      index  Size
# 0      51 to 200 employees   421
# 1         10000+ employees   375
# 2   1001 to 5000 employees   348
# 3        1 to 50 employees   347
# 4     201 to 500 employees   249
# 5    501 to 1000 employees   211
# 6  5001 to 10000 employees    97
# 7                  Unknown    42
